# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv('Student_Marks.csv')
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
pd.read_csv('ref.csv',sep=';')
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %%
df= pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %% [markdown]
# ## DATA OVERVIEW

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %% [markdown]
# ### DATA EXPLORATION

# %%
df[['team_id','fran_id']]
# Out:
#        team_id    fran_id
# 0          TRH    Huskies
# 1          NYK     Knicks
# 2          CHS      Stags
# 3          NYK     Knicks
# 4          DTF    Falcons
# ...        ...        ...
# 126309     CLE  Cavaliers
# 126310     GSW   Warriors
# 126311     CLE  Cavaliers
# 126312     CLE  Cavaliers
# 126313     GSW   Warriors
#
# [126314 rows x 2 columns]

# %%
df['team_id'].value_counts().head()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %%
df['fran_id'].value_counts().head()
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Name: fran_id, dtype: int64

# %%
df.loc[df['fran_id']=='Lakers']
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  ...  win_equiv  opp_id  \
# 1136             1            0     MNL  Lakers  ...  51.218754     BLB
# ...

# %%
df.loc[df['fran_id']=='Lakers',['team_id','fran_id']]
# Out:
#        team_id fran_id
# 1136       MNL  Lakers
# 1152       MNL  Lakers
# 1159       MNL  Lakers
# 1170       MNL  Lakers
# 1183       MNL  Lakers
# ...        ...     ...
# 126016     LAL  Lakers
# 126052     LAL  Lakers
# 126086     LAL  Lakers
# 126115     LAL  Lakers
# 126137     LAL  Lakers
#
# [6024 rows x 2 columns]

# %%
df.loc[df['fran_id']=='Falcons',['pts']]
# Out:
#      pts
# 4     33
# 17    49
# 25    71
# 29    69
# 42    68
# 56    70
# 63    57
# 71    53
# 85    54
# 93    68
# 100   66
# 117   68
# 127   57
# 132   47
# 138   57
# 145   65
# 160   64
# 167   66
# 176   66
# 178   66
# 189   66
# 202   49
# 221   92
# 232   51
# 244   48
# 258   62
# 268   50
# 280   61
# 282   80
# 298   58
# 315   68
# 327   74
# 338   57
# 345   47
# 359   55
# 367   66
# 377   73
# 401   65
# 409   46
# 422   64
# 432   74
# 440   84
# 465   58
# 468   59
# 474   51
# 480   76
# 503   61
# 515   68
# 531   74
# 548   67
# 551   65
# 563   61
# 579   81
# 596   61
# 600   59
# 610   75
# 620   85
# 627   63
# 636   63
# 648   66

# %% [markdown]
# ### QUERY

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df[
    df['year_id']>2010,
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-f308107550a7> in <module>
# ----> 1 df[
#       2     df['year_id']>2010,['pts']
#       3 ]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#    3082                 raise KeyError(key) from err
#
# ...

# %%
df[
    (df['year_id']>2010 )&
    (df['fran_id']=='Warriors') &
    (df['game_result']=='W')
][['year_id','fran_id','pts']]
# Out:
#         year_id   fran_id  pts
# 113668     2011  Warriors  132
# 113700     2011  Warriors  109
# 113767     2011  Warriors  115
# 113795     2011  Warriors   85
# 113853     2011  Warriors  109
# ...         ...       ...  ...
# 126301     2015  Warriors  104
# 126303     2015  Warriors  108
# 126308     2015  Warriors  103
# 126310     2015  Warriors  104
# 126313     2015  Warriors  105
#
# [249 rows x 3 columns]

# %%
# is_playoff nya 1
# fran_id lakers
# game location H
#year id 1970

df[
    (df['year_id']>1970 )&
    (df['fran_id']=='Lakers') &
    (df['game_location']=='H') &
    (df['is_playoffs']==1)
][['fran_id','is_playoffs','game_location','year_id']]
# Out:
#        fran_id  is_playoffs game_location  year_id
# 23811   Lakers            1             H     1971
# 23827   Lakers            1             H     1971
# 23898   Lakers            1             H     1971
# 23934   Lakers            1             H     1971
# 23970   Lakers            1             H     1971
# ...        ...          ...           ...      ...
# 118345  Lakers            1             H     2012
# 118367  Lakers            1             H     2012
# 118372  Lakers            1             H     2012
# 120926  Lakers            1             H     2013
# 120940  Lakers            1             H     2013
#
# [266 rows x 4 columns]

# %%
df.query("is_playoffs== 1,year_id>1970")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3471         try:
# -> 3472             result = self.loc[res]
#    3473         except ValueError:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1110                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
#
# ValueError: Cannot index with multidimensional key
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.groupby('fran_id')['pts'].mean()
# Out:
# fran_id
# Baltimore        79.698073
# Bombers          71.457831
# Bucks           103.700050
# Bulls           101.525192
# Capitols         76.931271
# Cavaliers        99.846719
# Celtics         104.466233
# Clippers        101.934905
# Colonels        111.625296
# Condors         115.446512
# Denver           77.709677
# Falcons          63.283333
# Floridians      112.654545
# Grizzlies        95.161738
# Hawks           101.805635
# Heat             96.627162
# Hornets          94.506711
# Huskies          66.583333
# Ironmen          61.233333
# Jazz            102.153305
# Jets             74.700000
# Kings           103.971689
# Knicks          100.970185
# Lakers          105.817397
# Magic            99.427277
# Mavericks       102.634915
# Nets            101.755723
# Nuggets         108.199029
# Olympians        81.078014
# Pacers          103.687722
# Packers          86.013889
# Pelicans         97.956522
# Pistons         101.373097
# Raptors          96.921665
# ...

# %%
df['game_location'].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
df.groupby('game_location')['pts'].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
grup=df.groupby('game_location')

# %%
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
df[
    (df['year_id']>2010 )&
    (df['pts']>120)  
].groupby('fran_id')[['pts']].mean().sort_values('pts',ascending=False)
# Out:
#                      pts
# fran_id
# Pacers        129.666667
# Jazz          128.300000
# Trailblazers  128.266667
# Bulls         128.111111
# Wizards       127.750000
# Pelicans      127.750000
# Nuggets       127.371429
# Nets          127.333333
# Thunder       126.741935
# Lakers        126.545455
# Raptors       126.500000
# Mavericks     126.333333
# Rockets       126.315789
# Clippers      126.241379
# Timberwolves  126.095238
# Pistons       126.000000
# Warriors      126.000000
# Hawks         126.000000
# Suns          125.750000
# Kings         125.684211
# Bucks         125.500000
# Cavaliers     125.266667
# Spurs         125.181818
# Heat          125.000000
# Magic         125.000000
# Grizzlies     124.333333
# Knicks        124.318182
# Celtics       124.000000
# Sixers        123.714286
# Hornets       122.600000

# %%
df[
    (df['year_id']>2010 )&
    (df['pts']>120) &
    (df['fran_id']=='Lakers')  
].groupby(['game_location','game_result'])[['pts']].mean().sort_values('pts',ascending=False)
# Out:
#                                pts
# game_location game_result
# H             L            127.500
#               W            126.375
# A             L            126.000

# %% [markdown]
# ### manipulasi kolom

# %%
df_new=df.copy()

# %%
#buat kolom
df_new['difference']=np.abs(df_new['pts']-df_new['opp_pts'])

# %%
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       68  1300.0000
# 1            0     NYK   Knicks  ...     TRH   Huskies       66  1300.0000
# 2            0     CHS    Stags  ...     NYK    Knicks       47  1306.7233
# 3            0     NYK   Knicks  ...     CHS     Stags       63  1300.0000
# 4            0     DTF  Falcons  ...     WSC  Capitols       50  1300.0000
#
#    opp_elo_n game_location  game_result  forecast  notes difference
# ...

# %%
#rename
df_new.rename(columns={
    'game_location':'loc',
    'game_result':'result'
},inplace=True)

# %%
df_new
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
df_new.drop(['elo_i','elo_n'],axis=1,inplace=True)

# %%
df_new
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
#create new column based on existing info using loop
# siapkan list kosong
# convert list yang sudah terisi menjadi kolom

hasil=[]

for i in range(len(df_new)):
    selisih = df_new.iloc[i,10] - df_new.iloc[i,14] # buat program loop >> selisih pts dengan opp_pts per baris
    hasil.append(selisih) # simpan hasil per baris ke list kosong

df_new['menggunakan_loop']=hasil

# %%
# tes

pts= df.iloc[:,10] # semua baris dalam kolom 10
opp = df.iloc[:,14]
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: int64

# %%
hasil
# Out:
# [-2,
#  2,
#  16,
#  -16,
#  -17,
#  17,
#  -6,
#  6,
#  -5,
#  5,
#  -11,
#  11,
#  -15,
#  15,
#  -2,
#  2,
#  4,
#  -4,
#  -6,
#  6,
#  8,
#  -8,
#  -5,
#  5,
#  2,
#  -2,
#  -8,
#  8,
#  -23,
#  23,
#  10,
#  -10,
#  1,
#  -1,
#  24,
#  -24,
#  10,
#  -10,
#  13,
#  -13,
#  -10,
#  10,
#  -2,
#  2,
#  3,
#  -3,
#  -2,
#  2,
#  -17,
#  17,
#  -4,
#  4,
#  8,
#  -8,
#  2,
#  -2,
#  11,
#  -11,
#  9,
#  -9,
#  -2,
#  2,
#  4,
#  -4,
#  -6,
#  6,
#  -3,
#  3,
#  2,
#  -2,
#  1,
#  -1,
#  3,
#  -3,
#  3,
#  -3,
#  -12,
#  12,
#  -2,
#  2,
#  8,
#  -8,
#  -1,
#  1,
#  -8,
#  8,
#  -6,
#  6,
#  -6,
#  6,
#  24,
#  -24,
#  -13,
#  13,
#  -2,
#  2,
#  12,
#  -12,
#  16,
#  -16,
#  20,
#  -20,
#  12,
#  -12,
#  -10,
#  10,
#  -7,
#  7,
#  -2,
#  2,
#  8,
#  -8,
#  -4,
#  4,
#  3,
#  -3,
#  -13,
#  13,
#  -2,
#  2,
#  -15,
#  15,
#  4,
#  -4,
#  -14,
#  14,
#  3,
#  -3,
#  9,
#  -9,
#  -10,
#  10,
#  -2,
#  2,
#  -2,
#  2,
#  -8,
#  8,
#  -13,
#  13,
#  11,
#  -11,
#  18,
#  -18,
#  -4,
# ...
